# %%
from rtnls_fundusprep.mask_extraction import get_cfi_bounds
from rtnls_fundusprep.utils import open_image

from matplotlib import pyplot as plt

# %%
# example with bounds only circle
filename = '/mnt/oogergo/ergo/OCT_ERGO/OCT_prd/b62656b8-288f-4320-a13b-0363b607067c/45548.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (1225.3166543664697, 812.970723823194)
#         - Radius: 804.4325224552936
#         - Top: 0
#         - Bottom: 1632
#         - Left: 0
#         - Right: 2464
# {'center': (1225.3166543664697, 812.970723823194), 'radius': 804.4325224552936, 'lines': {}}

# %%
# use crop function to fit the bounds to a rectangle
T, bounds_cropped = bounds.crop(64)
bounds_cropped.plot()

# transform object can also be used to apply inverse transform
image_restored = T.warp_inverse(bounds_cropped.image)
plt.imshow(image_restored)

# %%
# dark image with top and bottom cropped
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA_IBASE/ca46e62c-0e28-4706-9ffd-1df039dab820/4568V16B67JPGBXK.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (809.6251562668175, 504.5271593437189)
#         - Radius: 571.558710844449
#         - Top: 25
#         - Bottom: 985
#         - Left: 0
#         - Right: 1620
# {'center': (809.6251562668175, 504.5271593437189), 'radius': 571.558710844449, 'lines': {'top': array([[   0.        ,   19.27931807],
#        [1620.        ,   26.4717512 ]]), 'bottom': array([[   0.        ,  984.11617873],
#        [1620.        ,  989.50600786]])}}

# %%
# image left and right also cropped
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA/e5e6b58f-1e3d-4843-be85-0fcff9cbcc51/00704002-FUN-OS-20030515-001-001.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (701.0662903267399, 682.0482482810256)
#         - Radius: 516.8254720115093
#         - Top: 313
#         - Bottom: 1074
#         - Left: 229
#         - Right: 1359
# {'center': (701.0662903267399, 682.0482482810256), 'radius': 516.8254720115093, 'lines': {'top': array([[  -7.        ,  315.2352491 ],
#        [1365.        ,  303.11736068]]), 'bottom': array([[  -7.        , 1074.25948726],
#        [1365.        , 1074.9283977 ]]), 'left': array([[ 232.72238581,    0.        ],
#        [ 221.00598576, 1372.        ]]), 'right': array([[1220.9125197 ,    0.        ],
#        [1225.08450389, 1372.        ]])}}

# %%
# issue when additional artefacts are present
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA/af210591-682d-4c75-a2d0-73c12e9bfc44/00001823-FUN-OD-20040218-001-001.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (708.2213742126726, 692.5972791821491)
#         - Radius: 578.4944359035057
#         - Top: 309
#         - Bottom: 1074
#         - Left: 0
#         - Right: 1249
# {'center': (708.2213742126726, 692.5972791821491), 'radius': 578.4944359035057, 'lines': {'top': array([[  -7.        ,  307.36243228],
#        [1365.        ,  308.34777822]]), 'bottom': array([[  -7.        , 1075.27709432],
#        [1365.        , 1073.93162804]]), 'left': array([[ 100.82047107,    0.        ],
#        [  87.98131563, 1372.        ]]), 'right': array([[1251.26440132,    0.        ],
#        [1248.77714928, 1372.        ]])}}

# %%
# image right cropped (and spurious detection of left line)
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA/14cc92b1-e4ad-4df8-82fe-34de522743c2/00002164-EFN-OS-20030722-002-001.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (881.885908329333, 695.4718939093789)
#         - Radius: 426.1913860401982
#         - Top: 336
#         - Bottom: 1052
#         - Left: 467
#         - Right: 1249
# {'center': (881.885908329333, 695.4718939093789), 'radius': 426.1913860401982, 'lines': {'top': array([[  -6.5       ,  329.81060926],
#        [1364.5       ,  336.21761082]]), 'bottom': array([[  -6.5       , 1062.98873093],
#        [1364.5       , 1050.39491037]]), 'left': array([[ 5.22121144e+02, -5.00000000e-01],
#        [ 3.95517968e+02,  1.37050000e+03]]), 'right': array([[ 1.24996380e+03, -5.00000000e-01],
#        [ 1.24878902e+03,  1.37050000e+03]])}}

# %%
# bottom cropped diagonally
filename = '/mnt/oogergo/eyened/uitwissel/radboud_mahfam2023/extracted/056426/2011-08-24/CFP/R/1.2.276.0.43.100.18.201908141430052589151.1.2.1.dcm'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (1716.0447524434505, 908.8530886105957)
#         - Radius: 1347.448576674116
#         - Top: 0
#         - Bottom: 2025
#         - Left: 0
#         - Right: 3216
# {'center': (1716.0447524434505, 908.8530886105957), 'radius': 1347.448576674116, 'lines': {'top': array([[   0.        ,   -4.86976345],
#        [3216.        ,   -7.56416461]]), 'bottom': array([[   0.        , 1986.80859737],
#        [3216.        , 2117.64351632]])}}

# %%
# processed images available as cached properties
# sharpened and contrast enhanced are created using a smaller (256x256) blurred image
images = [
    bounds.mask, # crops at min and max x and y (not diagonal lines)
    bounds.mirrored_image, # mirrored image at full resolution
    bounds.sharpened_5, # sigma 5% of radius
    bounds.contrast_enhanced_2, # sigma 2% of radius
    bounds.contrast_enhanced_5, # sigma 5% of radius
    bounds.contrast_enhanced_10, # sigma 10% of radius
]
fig, axes = plt.subplots(1, 6, figsize=(20, 4))
for ax, image in zip(axes, images):
    ax.imshow(image)
plt.show()
