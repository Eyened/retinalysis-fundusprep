# %%
from rtnls_fundusprep.mask_extraction import get_cfi_bounds
from rtnls_fundusprep.utils import open_image

from matplotlib import pyplot as plt

# %%
# example with bounds only circle
filename = '/mnt/oogergo/ergo/OCT_ERGO/OCT_prd/b62656b8-288f-4320-a13b-0363b607067c/45548.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (1224.4980092643225, 813.0330328323248)
#         - Radius: 803.9615614619815
#         - Top: 0
#         - Bottom: 1632
#         - Left: 0
#         - Right: 2464
# {'center': (1224.4980092643225, 813.0330328323248), 'radius': 803.9615614619815, 'lines': {}}

# %%
# dark image with top and bottom cropped
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA_IBASE/ca46e62c-0e28-4706-9ffd-1df039dab820/4568V16B67JPGBXK.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (809.4821325636199, 504.72509074710894)
#         - Radius: 571.2467472119943
#         - Top: 25
#         - Bottom: 986
#         - Left: 0
#         - Right: 1620
# {'center': (809.4821325636199, 504.72509074710894), 'radius': 571.2467472119943, 'lines': {'top': array([[   0.        ,   19.16330187],
#        [1620.        ,   27.19125682]]), 'bottom': array([[   0.        ,  984.61558802],
#        [1620.        ,  989.97500209]])}}

# %%
# image left and right also cropped
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA/e5e6b58f-1e3d-4843-be85-0fcff9cbcc51/00704002-FUN-OS-20030515-001-001.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (700.8389696784669, 682.5618928158)
#         - Radius: 515.8350396621016
#         - Top: 313
#         - Bottom: 1071
#         - Left: 228
#         - Right: 1359
# {'center': (700.8389696784669, 682.5618928158), 'radius': 515.8350396621016, 'lines': {'top': array([[  -7.        ,  314.98251634],
#        [1365.        ,  303.40125855]]), 'bottom': array([[  -7.        , 1078.42733776],
#        [1365.        , 1068.77388469]]), 'left': array([[ 228.37604233,    0.        ],
#        [ 225.85066797, 1372.        ]]), 'right': array([[1223.03101916,    0.        ],
#        [1221.56451512, 1372.        ]])}}

# %%
# issue when additional artefacts are present
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA/af210591-682d-4c75-a2d0-73c12e9bfc44/00001823-FUN-OD-20040218-001-001.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (706.9374427455668, 688.8288126268394)
#         - Radius: 579.0056444342515
#         - Top: 308
#         - Bottom: 1073
#         - Left: 0
#         - Right: 1249
# {'center': (706.9374427455668, 688.8288126268394), 'radius': 579.0056444342515, 'lines': {'top': array([[  -7.        ,  307.30265526],
#        [1365.        ,  308.11766745]]), 'bottom': array([[  -7.        , 1075.09014903],
#        [1365.        , 1073.69862511]]), 'left': array([[  98.68959023,    0.        ],
#        [  89.69753514, 1372.        ]]), 'right': array([[1251.26440132,    0.        ],
#        [1248.77714928, 1372.        ]])}}

# %%
# image right cropped (and spurious detection of left line)
filename = '/mnt/oogergo/ergo/CF_ERGO/DATA/14cc92b1-e4ad-4df8-82fe-34de522743c2/00002164-EFN-OS-20030722-002-001.png'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (881.1077787700397, 695.9368825964364)
#         - Radius: 425.54564515622707
#         - Top: 336
#         - Bottom: 1048
#         - Left: 467
#         - Right: 1247
# {'center': (881.1077787700397, 695.9368825964364), 'radius': 425.54564515622707, 'lines': {'top': array([[  -6.5       ,  340.72035722],
#        [1364.5       ,  329.2669443 ]]), 'bottom': array([[  -6.5       , 1070.93648933],
#        [1364.5       , 1043.5249295 ]]), 'left': array([[ 5.24781506e+02, -5.00000000e-01],
#        [ 3.92033684e+02,  1.37050000e+03]]), 'right': array([[ 1.25077618e+03, -5.00000000e-01],
#        [ 1.24538109e+03,  1.37050000e+03]])}}

# %%
# bottom cropped diagonally
filename = '/mnt/oogergo/eyened/uitwissel/radboud_mahfam2023/extracted/056426/2011-08-24/CFP/R/1.2.276.0.43.100.18.201908141430052589151.1.2.1.dcm'

img = open_image(filename)
bounds = get_cfi_bounds(img)

bounds.plot()
display(bounds)
print(bounds.to_dict())
# Out:
# #### Bounds:
#
#         - Center: (1716.0671600659848, 907.0283618476135)
#         - Radius: 1347.8314421205996
#         - Top: 0
#         - Bottom: 2028
#         - Left: 0
#         - Right: 3216
# {'center': (1716.0671600659848, 907.0283618476135), 'radius': 1347.8314421205996, 'lines': {'top': array([[   0.        ,   -5.86332264],
#        [3216.        ,   -7.01764763]]), 'bottom': array([[   0.        , 1992.77818067],
#        [3216.        , 2112.86503708]])}}

# %%
# processed images available as cached properties
# sharpened and contrast enhanced are created using a smaller (256x256) blurred image
images = [
    bounds.mask, # crops at min and max x and y (not diagonal lines)
    bounds.mirrored_image, # mirrored image at full resolution
    bounds.sharpened_5, # sigma 5% of radius
    bounds.contrast_enhanced_2, # sigma 2% of radius
    bounds.contrast_enhanced_5, # sigma 5% of radius
    bounds.contrast_enhanced_10, # sigma 10% of radius
]
fig, axes = plt.subplots(1, 6, figsize=(20, 4))
for ax, image in zip(axes, images):
    ax.imshow(image)
plt.show()
